# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
vehicle_path = 'D:\Work\Projects\Advanced-Research\Dataset\Vehicle Data'
charging_path = 'D:\Work\Projects\Advanced-Research\Dataset\Charging Data'


def framer(folderPath):

    df_list = []

    for fileName in os.listdir(path):
        if fileName.endswith('.csv'):
            filePath = os.path.join(path, fileName)

            df_list.append(pd.read_csv(filePath))


    merged_df = pd.concat(df_list, ignore_index=True)

    return merged_df


vehicleDF = framer(vehicle_path)
chargingDF = framer(charging_path)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\us392\AppData\Local\Temp\ipykernel_9340\3453087532.py:1: SyntaxWarning: invalid escape sequence '\W'
#   vehicle_path = 'D:\Work\Projects\Advanced-Research\Dataset\Vehicle Data'
# C:\Users\us392\AppData\Local\Temp\ipykernel_9340\3453087532.py:2: SyntaxWarning: invalid escape sequence '\W'
#   charging_path = 'D:\Work\Projects\Advanced-Research\Dataset\Charging Data'

# %%
vehicleDF.dropna(axis=0, thresh=)
# Out:
# Empty DataFrame
# Columns: [Vehicle ID, Date, Number of Trips, Total Distance, Idling Time, Driving Time, Total Run Time, Initial SOC, Final SOC, SOC Used, Total Energy Consumption, Average Ambient Temperature, Initial Odometer, Final Odometer, Local Trip Start Time, Local Trip End Time, Percent Idling Time, Trip Percent Idling Time, Drive Cycle, Average Ambient Temperature (logger), Average Speed, GPS Average Speed, GPS Distance, Average Battery Voltage, Average Battery Power Used, Average Battery Current, Max SOC, Min SOC, Energy Consumed While Driving, Energy Consumed While Idling, Maximum Speed, HV Acces. Energy, LV Acces. Energy, Elect. Heater Energy, Traction Energy, Ending Odometer, Charging Time, SOC Used for Driving, SOC Used for Idling, Total Energy Charged, Total Energy Driven, Total Energy Idled, Total Energy Regenerated from Driving, HV Accessories Energy, LV Accessories Energy, Electric Heater Energy, Regenerated Energy]
# Index: []
#
# [0 rows x 47 columns]

# %%
chargingDF
# Out:
#       Vehicle ID            Date  Number of Trips  Total Distance  \
# 0          EV001  11/1/2016 4:00              NaN        1.400000
# 1          EV001  11/2/2016 4:00              NaN        4.500000
# 2          EV001  11/3/2016 4:00              NaN        1.300000
# 3          EV001  11/7/2016 4:00              NaN       71.800000
# 4          EV001  11/8/2016 4:00              NaN       71.600000
# ...          ...             ...              ...             ...
# 81082      EV229      12/18/2023              NaN       34.197273
# 81083      EV229      12/19/2023              NaN       44.667037
# 81084      EV229      12/20/2023              NaN       52.966096
# 81085      EV229      12/21/2023              NaN       22.145375
# 81086      EV229      12/27/2023              NaN        0.994194
#
#        Idling Time  Driving Time Total Run Time  Initial SOC  Final SOC  \
# 0         0.176925      0.222297       0.399222          NaN        NaN
# ...

# %%
workableDataframe = pd.merge(vehicleDF, chargingDF, on='Vehicle ID', how='inner')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 workableDataframe = pd.merge(vehicleDF, chargingDF, on='Vehicle ID', how='inner')
#
# File c:\Users\us392\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\Users\us392\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# ...
